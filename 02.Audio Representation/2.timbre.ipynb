# %%
# %matplotlib inline
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display

# %% [markdown]
# ## 1. Timbre
#
# ### Pure tone
#
# Let's synthesize a **pure tone** at 1047 Hz, concert C6:

# %%
T = 2.0 # seconds
f0 = 1047.0
sr = 22050
t = numpy.linspace(0, T, int(T*sr), endpoint=False) # time variable
x = 0.1*numpy.sin(2*numpy.pi*f0*t)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Display the spectrum of the pure tone:

# %%
X = scipy.fft(x[:4096])
X_mag = numpy.absolute(X)        # spectral magnitude
f = numpy.linspace(0, sr, 4096)  # frequency variable
plt.figure(figsize=(14, 5))
plt.plot(f[:2000], X_mag[:2000]) # magnitude spectrum
plt.xlabel('Frequency (Hz)')
# Out:
# Text(0.5, 0, 'Frequency (Hz)')

# %% [markdown]
# ### Oboe
# Let's listen to an **oboe** playing a C6:

# %%
x, sr = librosa.load('./oboe_c6.wav')
print(x.shape)
ipd.Audio(x, rate=sr)
# Out:
# (23625,)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Display the spectrum of the oboe:

# %%
X = scipy.fft(x[10000:14096])
X_mag = numpy.absolute(X)
plt.figure(figsize=(14, 5))
plt.plot(f[:2000], X_mag[:2000]) # magnitude spectrum
plt.xlabel('Frequency (Hz)')
# Out:
# Text(0.5, 0, 'Frequency (Hz)')

# %% [markdown]
# ### Clarinet
#
# Let's listen to a **clarinet** playing a concert C6:

# %%
x, sr = librosa.load('./clarinet_c6.wav')
print(x.shape)
ipd.Audio(x, rate=sr)
# Out:
# (51386,)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
X = scipy.fft(x[10000:14096])
X_mag = numpy.absolute(X)
plt.figure(figsize=(14, 5))
plt.plot(f[:2000], X_mag[:2000]) # magnitude spectrum
plt.xlabel('Frequency (Hz)')
# Out:
# Text(0.5, 0, 'Frequency (Hz)')

# %% [markdown]
# All three signals have approximately the same pitch and fundamental frequency, yet their timbres differ.
